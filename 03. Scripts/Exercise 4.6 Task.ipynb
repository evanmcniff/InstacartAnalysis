# %% [markdown]
# # Importing Libraries and Data

# %%
# Libraries
import pandas as pd
import numpy as np
import os

# %%
# Data Path
path = r'/Users/Evan/Desktop/Instacart Analysis'

# %%
# Importing Orders_products_combined data
df_opc = pd.read_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# Importing Product Data
df_prod = pd.read_csv(os.path.join(path, '02. Data', 'Prepared Data', 'prod_checked.csv'))

# %% [markdown]
# # Checking Data

# %%
# checking shape
df_opc.shape
# Out:
# (32434489, 13)

# %%
df_opc.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  order_number  \
# 0             0           0   2539329        1    prior             1
# 1             0           0   2539329        1    prior             1
# 2             0           0   2539329        1    prior             1
# 3             0           0   2539329        1    prior             1
# 4             0           0   2539329        1    prior             1
#
#    order_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                  2                  8                     NaN         196
# 1                  2                  8                     NaN       14084
# 2                  2                  8                     NaN       12427
# 3                  2                  8                     NaN       26088
# 4                  2                  8                     NaN       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# ...

# %%
df_prod.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
# drop unnamed columns
df_prod = df_prod.drop(columns = ['Unnamed: 0'])

# %%
# Drop merge columns (unnamed columns dropped as well)
df_opc = df_opc.drop(columns = ['_merge'])

# %% [markdown]
# # Merging Data

# %%
df_merged = df_prod.merge(df_opc, on = 'product_id', indicator = True)

# %% [markdown]
# # Merge Confirmation

# %%
df_merged
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  \
# ...

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_merged.drop(columns = ['_merge'])
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  Unnamed: 0.1  Unnamed: 0  order_id  user_id eval_set  \
# ...

# %%
df_merged.drop(columns = ['Unnamed: 0.1', 'Unnamed: 0'])
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id eval_set  order_number  order_day_of_week  \
# ...

# %% [markdown]
# # Exporting Files

# %%
df_merged.to_pickle(os.path.join(path, '02. Data', 'Prepared Data', 'orders_products_merged.pkl'))
